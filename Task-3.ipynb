# %%
# !pip install pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load Dataset
df = pd.read_csv("scraped_job_data.csv")

# Set style
sns.set_style("whitegrid")

print("=" * 50)
print("CODEALPHA TASK 3 - DATA VISUALIZATION")
print("=" * 50)
# Out:
# ...
# CODEALPHA TASK 3 - DATA VISUALIZATION
# ...

# %%
# -----------------------------
# 1. Top Hiring Companies
# -----------------------------

top_companies = df["Company"].value_counts().head(10)

plt.figure(figsize=(12,6))
sns.barplot(
    x=top_companies.values,
    y=top_companies.index
)

plt.title("Top 10 Hiring Companies")
plt.xlabel("Number of Job Openings")
plt.ylabel("Company")
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# 2. Top Job Locations
# -----------------------------

top_locations = df["Location"].value_counts().head(10)

plt.figure(figsize=(12,6))
sns.barplot(
    x=top_locations.values,
    y=top_locations.index
)

plt.title("Top 10 Job Locations")
plt.xlabel("Number of Jobs")
plt.ylabel("Location")
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# 3. Most Common Job Titles
# -----------------------------

top_jobs = df["Job Title"].value_counts().head(10)

plt.figure(figsize=(12,6))
sns.barplot(
    x=top_jobs.values,
    y=top_jobs.index
)

plt.title("Top 10 Job Titles")
plt.xlabel("Frequency")
plt.ylabel("Job Title")
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# 4. Pie Chart of Top 5 Companies
# -----------------------------

top5 = df["Company"].value_counts().head(5)

plt.figure(figsize=(8,8))
plt.pie(
    top5.values,
    labels=top5.index,
    autopct="%1.1f%%"
)

plt.title("Market Share of Top 5 Hiring Companies")
plt.show()

# %%
# -----------------------------
# 5. Job Posting Timeline
# -----------------------------

df["Date Posted"] = pd.to_datetime(
    df["Date Posted"],
    errors="coerce"
)

timeline = df["Date Posted"].value_counts().sort_index()

plt.figure(figsize=(12,6))
plt.plot(
    timeline.index,
    timeline.values,
    marker="o"
)

plt.title("Job Posting Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Number of Jobs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
# -----------------------------
# 6. Heatmap
# -----------------------------

company_location = pd.crosstab(
    df["Company"],
    df["Location"]
)

plt.figure(figsize=(12,8))
sns.heatmap(
    company_location,
    cmap="YlGnBu"
)

plt.title("Company vs Location Heatmap")
plt.tight_layout()
plt.show()

print("\nVisualization Completed Successfully!")
# Out:
# Visualization Completed Successfully!
